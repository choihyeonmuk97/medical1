# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows 한글 폰트
matplotlib.rcParams['font.size'] = '10' # font size
matplotlib.rcParams['axes.unicode_minus'] = False # - 기호 깨짐 현상을 해결함
import numpy as np

# %%
values = [30,25,20,13,10,2] # hap 100
labels = ['Python','Java','Javascript','C#','C','ETC']
explode = [0.1]*6
colors = ['r','orange','y','g','b','m']
wedgeprops={'width':0.6, 'edgecolor':'w','linewidth':2}

# plt.pie(values,labels=labels, autopct='%.1f%%',explode=explode,startangle=90,counterclock=False,colors=colors, wedgeprops=wedgeprops)
plt.pie(values,labels=labels, autopct='%.1f%%',startangle=90,counterclock=False,colors=colors, wedgeprops=wedgeprops,pctdistance=0.7)
plt.legend(loc=(1.1,0.3))
plt.show()

# %%
plt.pie(values,labels=labels, autopct='%.1f%%',explode=explode,startangle=90,counterclock=False,colors=colors, wedgeprops=wedgeprops)
plt.show()
