# %%
from sklearn import svm,metrics
from sklearn.neighbors import KNeighborsClassifier # 분류
from sklearn.neighbors import KNeighborsRegressor # 회귀(예측)
from sklearn.model_selection import train_test_split # 데이터 나눔
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
matplotlib.rcParams['axes.unicode_minus'] = False  # 마이너스 표시 해결
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # windows 사용자 한글설정
matplotlib.rcParams['font.size'] = '10' # 글자크기

# %%
# numpy 라이브러리 사용
perch_length = np.array([8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 
     21.0, 21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 
     22.5, 22.7, 23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 
     27.3, 27.5, 27.5, 27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 
     36.5, 36.0, 37.0, 37.0, 39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 
     40.0, 42.0, 43.0, 43.0, 43.5, 44.0])

perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 
     110.0, 115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 
     130.0, 150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 
     197.0, 218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 
     514.0, 556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 
     820.0, 850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 
     1000.0, 1000.0])

# %%
# 산점도
plt.scatter(perch_length,perch_weight)

# %%
# 데이터 전처리 - train,test 세트 구성
# random_state = : 랜덤으로 섞는 것을 고정시켜 예측률 고정
train_input,test_input,train_target,test_target = train_test_split(
    perch_length,perch_weight,random_state=42)

# %%
# 1차원 데이터를 2차원 행렬로 변경
train_input = train_input.reshape(-1,1)
test_input = test_input.reshape(-1,1)

# %%
train_input.shape
# Out:
# (42, 1)

# %%
# 데이터 훈련
knr = KNeighborsRegressor() # knn 회귀(예측)
knr.fit(train_input,train_target)
# Out:
# KNeighborsRegressor()

# %%
predict = knr.predict(test_input)
print('예측값 :',predict)
# Out:
# 예측값 : [  60.    79.6  248.   122.   136.   847.   311.4  183.4  847.   113.
#  1010.    60.   248.   248. ]

# %%
plt.scatter(test_input,test_target) # 실제 값
plt.scatter(test_input,predict) # 예측 값

# %%
score = knr.score(train_input,train_target)
print('train 예측률 :',score)

score = knr.score(test_input,test_target)
print('test 예측률 :',score)

# 과소적합이 되었다고 판단 -> n_neighbors 의 개수를 줄임
# Out:
# train 예측률 : 0.9698823289099254
# test 예측률 : 0.992809406101064

# %%
knr.n_neighbors=3 # 기본 값 5
knr.fit(train_input,train_target)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
score = knr.score(train_input,train_target)
print('train 예측률 :',score)

score = knr.score(test_input,test_target)
print('test 예측률 :',score)

# 과소적합 해소
# Out:
# train 예측률 : 0.9804899950518966
# test 예측률 : 0.9746459963987609

# %%
predict = knr.predict([[16.8]])
print(predict)
# Out:
# [62.66666667]

# %%
# 5의 배수 45까지 (5,10,15,20,25,30,35,40,45) - 길이
# 그래프로 출력?
knr.n_neighbors = 3
x = np.arange(5,46,5).reshape(-1,1)
predict = knr.predict(x)
plt.scatter(train_input,train_target)
plt.plot(x,predict,'y') 
# for i in x:
#     i = i.reshape(-1,1)
#     predict = knr.predict(i)
#     print(predict)
